# %%
############### Set working directory to parent directory
import os, nltk, numpy as np, pandas as pd
from nltk import word_tokenize

os.getcwd()
# os.chdir('F:\\github\\narrative_conservatism\\code')
# Out:
# 'F:\\github\\narrative_conservatism\\code'

# %%
#####################################################################
#####################FOR ALL PROCESSED FILES LOOP####################
#####################################################################

############# Create processed txt file index
processed = list()
for subdir, dirs, files in os.walk("..\\filings\\processed"):
    for file in files:
        processed.append(os.path.join(subdir, file))
        
############# Create an array of file number
accnum = list()

for file in processed:
    a = file.split("\\")[3].split(".")[0]
    accnum.append(a)

# %%
############ Word Tokenization, count nword and nvocab
nw_all = list()
nvocab_all = list()

for text in processed:
    ############# Read processed txt file
    with open(text, 'r',  encoding = "utf-8") as file:
        contents = file.read().replace('\n', '').replace('\xa0', '')
        # print(repr(contents))
        
        ############ Word Tokenization
        ## Raw tokens: including punctuations, numbers etc.
        tokens = word_tokenize(contents)

        ## Convert all words into small cases
        ## And keep tokens that purely consist of alphabetic characters only
        words = [w.lower() for w in tokens if w.isalpha()]
        
        ########### Delete words with lenth smaller than 1% and largr than 99% of the document
        wordlen99 = np.quantile([len(w) for w in words], 0.99)
        wordlen1 = np.quantile([len(w) for w in words], 0.01)
        words = [w for w in words if len(w)<wordlen99 and len(w)>wordlen1]
        vocab = sorted(set(words))
        #vocab[:20]
        
        ########### Save text statistics
        ##### 1. nw: 1) nw_all 2) nw_mda 3) nw_notes
        ##### 2. nvocab: 1) nvvocab_all 2) nvocab_mda 3) nvocab_notes
        ##### 3. tone: 1) tone_all 2) tone_mda 3) tone_notes
        
        ## 1.1) nw_all
        a = len(words)
        nw_all.append(a)
        
        ## 2.1) nvocab_all
        b = len(vocab)
        nvocab_all.append(b)

# %%
############### Create Data Frame
d = {'filenum': accnum, 'nw_all': nw_all, 'nvocab_all': nvocab_all}
text_data = pd.DataFrame(data=d)

text_data
# Out:
#                   filenum  nw_all  nvocab_all
# 0    0000008670-20-000007   10584        1367
# 1    0000008858-20-000009    8862        1147
# 2    0000008947-20-000012    7032        1222
# 3    0000074046-20-000009   10323        1394
# 4    0000076334-20-000009    8028        1233
# ..                    ...     ...         ...
# 195  0001663577-20-000033   12250        2048
# 196  0001683168-20-000123   10109        1729
# 197  0001683168-20-000440   11446        1737
# 198  0001683168-20-000464    5491        1212
# 199  0001728949-20-000011   27059        2538
#
# [200 rows x 3 columns]

# %%
#####################################################################
###################FOR SINGLE FILE INSPECTION########################
#####################################################################

############ Word Tokenization
## Raw tokens: including punctuations, numbers etc.
with open(processed[1], 'r',  encoding = "utf-8") as file:
    contents = file.read().replace('\n', '').replace('\xa0', '')
tokens = word_tokenize(contents)

#tokens

## Convert all words into small cases
## And keep tokens that purely consist of alphabetic characters only
words = [w.lower() for w in tokens if w.isalpha()]

#words

# %%
########### Winsorize words with lenth smaller than 1% and largr than 99% of the document
wordlen99 = np.quantile([len(w) for w in words], 0.99)
wordlen1 = np.quantile([len(w) for w in words], 0.01)
words = [w for w in words if len(w)<wordlen99 and len(w)>wordlen1]
vocab = sorted(set(words))

# vocab[:20]

# %%
######### See the most common 20 words
# fdist = nltk.FreqDist(words)
# fdist.most_common(30)

# %%
############### Set working directory to parent directory
import os
os.getcwd()
# os.chdir('F:\\github\\narrative_conservatism\\code')
# Out:
# 'F:\\github\\narrative_conservatism\\code'

# %%
#####################################################################
#####################FOR ALL PROCESSED FILES LOOP####################
#####################################################################

############# Create processed txt file index
import os
# os.chdir('F:\\github\\narrative_conservatism\\code')

processed = list()
for subdir, dirs, files in os.walk("..\\filings\\processed"):
    for file in files:
        processed.append(os.path.join(subdir, file))

# %%
############# Create an array of file number
filenum = list()

for file in processed:
    a = file.split("\\")[3].split(".")[0]
    filenum.append(a)

# %%
import nltk
from nltk import word_tokenize
import numpy as np

nw_all = list()
nvocab_all = list()

for text in processed:
    ############# Read processed txt file
    with open(text, 'r',  encoding = "utf-8") as file:
        contents = file.read().replace('\n', '').replace('\xa0', '')
        #print(repr(contents))
        
        ############ Word Tokenization
        ## Raw tokens: including punctuations, numbers etc.
        tokens = word_tokenize(contents)

        ## Convert all words into small cases
        ## And keep tokens that purely consist of alphabetic characters only
        words = [w.lower() for w in tokens if w.isalpha()]
        
        ########### Winsorize words with lenth smaller than 1% and largr than 99% of the document
        wordlen99 = np.quantile([len(w) for w in words], 0.99)
        wordlen1 = np.quantile([len(w) for w in words], 0.01)
        words = [w for w in words if len(w)<wordlen99 and len(w)>wordlen1]
        vocab = sorted(set(words))
        #vocab[:20]
        
        ########### Save text statistics
        ##### 1. nw: 1) nw_all 2) nw_mda 3) nw_notes
        ##### 2. nvocab: 1) nvvocab_all 2) nvocab_mda 3) nvocab_notes
        ##### 3. tone: 1) tone_all 2) tone_mda 3) tone_notes
        
        ## 1.1) nw_all
        a = len(words)
        nw_all.append(a)
        
        ## 2.1) nvocab_all
        b = len(vocab)
        nvocab_all.append(b)

# %%
############### Create Data Frame
import pandas as pd

d = {'filenum': filenum, 'nw': nw, 'nvocab': nvocab}
text_data = pd.DataFrame(data=d)

text_data
# Out:
#                  filenum     nw  nvocab
# 0   0000051143-13-000007  26711    3294
# 1   0000051143-14-000004  23912    3486
# 2   0000051143-14-000007  28478    3671
# 3   0000051143-14-000010  30749    3785
# 4   0000051143-15-000003  25344    3642
# 5   0000051143-15-000005  30074    3743
# 6   0000051143-15-000009  30460    3809
# 7   0000051143-16-000013  25790    3557
# 8   0001104659-06-069905  18100    2831
# 9   0001104659-07-030840  13017    2486
# 10  0001104659-07-057458  18125    2892
# 11  0001104659-07-078049  17260    2683
# 12  0001104659-08-027817  15768    2828
# 13  0001104659-08-048278  19456    2966
# 14  0001104659-08-066201  20387    3031
# 15  0001104659-09-026661  17224    2922
# 16  0001104659-09-045198  22333    3178
# 17  0001104659-09-060554  22661    3195
# 18  0001104659-10-022064  20583    3149
# 19  0001104659-10-039808  24482    3311
# 20  0001104659-10-053716  24204    3307
# 21  0001104659-11-022352  22738    2219
# 22  0001104659-11-040759  26910    2088
# 23  0001104659-11-057630  26836    2216
# 24  0001104659-12-027715  22375    2181
# 25  0001104659-12-052637  27481    2261
# 26  0001104659-12-072210  27830    2279
# 27  0001104659-13-035106  24056    2276
# 28  0001104659-13-058041  28851    2278
# 29  0001104659-16-134367  32514    2455
# 30  0001104659-16-151931  32121    2440
# 31  0001104659-17-025881  26244    2266
# 32  0001104659-17-046808  30287    2302
# 33  0001104659-17-064968  30799    2337
# 34  0001104659-18-026178  29294    2339
# 35  0001104659-18-048404  34472    2397
# 36  0001104659-18-064673  34819    2427
# 37  0001104659-19-025328  27555    2299
# 38  0001558370-19-006560  31828    2401
# 39  0001558370-19-009324  33375    2433

# %%
#####################################################################
###################FOR SINGLE FILE INSPECTION########################
#####################################################################

############ Word Tokenization
## Raw tokens: including punctuations, numbers etc.
tokens = word_tokenize(contents)

## Convert all words into small cases
## And keep tokens that purely consist of alphabetic characters only
words = [w.lower() for w in tokens if w.isalpha()]

# %%
########### Winsorize words with lenth smaller than 1% and largr than 99% of the document
import numpy as np
wordlen99 = np.quantile([len(w) for w in words], 0.99)
wordlen1 = np.quantile([len(w) for w in words], 0.01)
words = [w for w in words if len(w)<wordlen99 and len(w)>wordlen1]
vocab = sorted(set(words))

# vocab[:20]

# %%
######### See the most common 20 words
# fdist = nltk.FreqDist(words)
# fdist.most_common(50)

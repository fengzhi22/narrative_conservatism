# %%
import pandas as pd
import numpy as np

id_data = pd.read_csv('filings\\id_data_8-K.csv', usecols = ['accnum', 'cik', 'fd', 'rp'])
crsp_comp = pd.read_csv('filings\\crsp_comp_8-K.csv', usecols = ['date', 'cusip', 'cik', 'datadate', 'gvkey'])

pd.set_option('display.max_rows', None)

# %%
id_data = id_data[(id_data['cik'] == 51143) | (id_data['cik'] == 320193)]

# %%
crsp_comp = crsp_comp[(crsp_comp['cik'] == 51143) | (crsp_comp['cik'] == 320193)]

# %%
### Prepare merge
id_data['fd'] = pd.to_datetime(id_data['fd'])
id_data['date_key'] = pd.to_datetime(id_data['rp'])
id_data['rp'] = pd.to_datetime(id_data['rp'])
crsp_comp['date_key'] = crsp_comp['date'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m%d'))
crsp_comp['date'] = crsp_comp['date'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m%d'))
crsp_comp['datadate'] = crsp_comp['datadate'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m%d'))
# crsp_comp_ibm['ipodate'] = crsp_comp_ibm['ipodate'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m%d'))

# %%
crsp_comp[:100]
# Out:
#             date     cusip      cik   datadate   gvkey   date_key
# 42845 1993-03-31  45920010  51143.0 1993-03-31  6066.0 1993-03-31
# 42846 1993-06-30  45920010  51143.0 1993-06-30  6066.0 1993-06-30
# 42847 1993-09-30  45920010  51143.0 1993-09-30  6066.0 1993-09-30
# 42848 1993-12-31  45920010  51143.0 1993-12-31  6066.0 1993-12-31
# 42849 1994-03-31  45920010  51143.0 1994-03-31  6066.0 1994-03-31
# 42850 1994-06-30  45920010  51143.0 1994-06-30  6066.0 1994-06-30
# 42851 1994-09-30  45920010  51143.0 1994-09-30  6066.0 1994-09-30
# 42852 1994-12-30  45920010  51143.0 1994-12-31  6066.0 1994-12-30
# 42853 1995-03-31  45920010  51143.0 1995-03-31  6066.0 1995-03-31
# 42854 1995-06-30  45920010  51143.0 1995-06-30  6066.0 1995-06-30
# 42855 1995-09-29  45920010  51143.0 1995-09-30  6066.0 1995-09-29
# 42856 1995-12-29  45920010  51143.0 1995-12-31  6066.0 1995-12-29
# 42857 1996-03-29  45920010  51143.0 1996-03-31  6066.0 1996-03-29
# ...

# %%
id_data[:100]
# Out:
#                       accnum     cik         fd         rp   date_key
# 8531    0000950157-95-000318   51143 1995-10-30 1995-10-30 1995-10-30
# 10602   0000950157-96-000083   51143 1996-03-08 1996-02-08 1996-02-08
# 12830   0000320193-96-000006  320193 1996-04-12 1996-04-10 1996-04-10
# 12831   0000320193-96-000014  320193 1996-06-17 1996-06-14 1996-06-14
# 16921   0000891554-96-000459   51143 1996-07-26 1996-07-25 1996-07-25
# 21528   0000912057-96-023874  320193 1996-10-28 1996-10-28 1996-10-28
# 21529   0000320193-96-000021  320193 1996-12-13 1996-12-04 1996-12-04
# 21530   0000320193-96-000027  320193 1996-12-24 1996-12-24 1996-12-24
# 21807   0000912057-96-023401   51143 1996-10-22 1996-10-21 1996-10-21
# 21808   0000950157-96-000435   51143 1996-12-05 1996-12-03 1996-12-03
# 27286   0001005477-97-000064   51143 1997-01-23 1997-01-21 1997-01-21
# 27287   0001005477-97-000100   51143 1997-01-29 1997-01-28 1997-01-28
# ...

# %%
id_crsp_comp = pd.merge(id_data, crsp_comp, on = ['cik', 'date_key'], how = 'outer', validate = 'm:m')

# %%
id_crsp_comp.sort_values(by=['cik', 'date_key'])
# Out:
#                    accnum     cik         fd         rp   date_key       date  \
# 631                   NaN   51143        NaT        NaT 1993-03-31 1993-03-31
# 632                   NaN   51143        NaT        NaT 1993-06-30 1993-06-30
# 633                   NaN   51143        NaT        NaT 1993-09-30 1993-09-30
# 634                   NaN   51143        NaT        NaT 1993-12-31 1993-12-31
# 635                   NaN   51143        NaT        NaT 1994-03-31 1994-03-31
# 636                   NaN   51143        NaT        NaT 1994-06-30 1994-06-30
# 637                   NaN   51143        NaT        NaT 1994-09-30 1994-09-30
# 41   0001047469-99-029828   51143 1999-08-05 1994-12-13 1994-12-13        NaT
# 638                   NaN   51143        NaT        NaT 1994-12-30 1994-12-30
# 639                   NaN   51143        NaT        NaT 1995-03-31 1995-03-31
# 47   0000912057-00-021817   51143 2000-05-05 1995-06-14 1995-06-14        NaT
# ...
